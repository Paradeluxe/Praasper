# %%
import praasper


model = praasper.init_model(
    ASR="FunAudioLLM/Fun-ASR-Nano-2512",
    infer_mode="direct",
    device="auto",
    LLM= "Qwen/Qwen3-4B-Instruct-2507"# "Qwen/Qwen3-8B"
)
# Out:
# [09:21:514] Initializing model with FunAudioLLM/Fun-ASR-Nano-2512
# Current model requires 512 bytes of buffer for offloaded layers, which seems does not fit any GPU's remaining memory. If you are experiencing a OOM later, please consider using offload_buffers=True.
# Loading weights: 100%|██████████| 398/398 [00:00<00:00, 818.13it/s, Materializing param=model.norm.weight]
# ...
# WARNING:root:trust_remote_code: True
# Loading remote code failed: model, No module named 'model'
# [10:21:943] Using device: cuda:0

# %%
# audio_obj = ReadSound(r"C:\Users\User\Desktop\Praditor\resources\test_audio\test_audio.wav")
model.autoplay(r"C:\Users\User\Desktop\Praditor\resources\test_audio\test_audio.wav")
# Out:
# 考察编辑机场冰箱

# %%
from praasper.process import auto_vad


vad_tg = auto_vad(r"C:\Users\User\Desktop\Praditor\resources\test_audio\test_audio.wav", min_pause=0.2)
# Out:
# [00:05:760] (test_audio.wav) VAD processing started...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 4
#       1 from praasper.process import auto_vad
# ----> 4 vad_tg = auto_vad(r"C:\Users\User\Desktop\Praditor\resources\test_audio\test_audio.wav", min_pause=0.2)
#
# File c:\Users\User\Desktop\Praasper\praasper\process.py:310, in auto_vad(wav_path, min_pause, if_save, verbose)
#     307 adjusted_params = params.copy()
#     309 for p in params:
# --> 310     adjusted_params["onset"][p] = str(adjusted_params[p])
#     312 adjusted_params["offset"] = adjusted_params["onset"]
#     314 print(adjusted_params)
#
# KeyError: 'onset'
